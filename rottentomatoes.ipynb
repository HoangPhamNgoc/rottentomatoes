# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datalab
import re

from sklearn.feature_extraction.text import CountVectorizer
from google.cloud import bigquery
from collections import Counter
# %matplotlib inline
sns.set_style("whitegrid")

# %%
# Load data
df = pd.read_csv('train.csv', index_col='Unnamed: 0')

# %%
df.sample(5)
# Out:
#        PhraseId  SentenceId  \
# 17493    123677        6641
# 7070      78906        4060
# 83002    109379        5792
# 59114     78043        4017
# 73633    115088        6131
#
#                                                   Phrase  Sentiment
# 17493                                          Hurley 's          2
# 7070   can tell you that there 's no other reason why...          1
# 83002                                    nature\/nurture          2
# 59114                       her small , intelligent eyes          3
# 73633                   incredibly layered and stylistic          3

# %%
# Extract feature from Phrase
count = CountVectorizer()
bag = count.fit_transform(df['Phrase'])

# %%
count.get_feature_names()
# Out:
# ['000',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '10th',
#  '11',
#  '110',
#  '112',
#  '12',
#  '120',
#  '127',
#  '129',
#  '12th',
#  '13',
#  '13th',
#  '14',
#  '140',
#  '146',
#  '15',
#  '15th',
#  '16',
#  '163',
#  '168',
#  '170',
#  '1790',
#  '18',
#  '1899',
#  '19',
#  '1915',
#  '1920',
#  '1930s',
#  '1933',
#  '1937',
#  '1938',
#  '1940s',
#  '1950',
#  '1950s',
#  '1952',
#  '1953',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1960s',
#  '1962',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1979',
#  '1980',
#  '1980s',
#  '1984',
#  '1986',
#  '1987',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '20',
#  '2000',
#  '2001',
#  '2002',
#  '20th',
#  '21',
#  '21st',
#  '22',
#  '24',
#  '2455',
#  '25',
#  '26',
#  '270',
#  '295',
#  '30',
#  '300',
#  '3000',
#  '30s',
#  '37',
#  '3d',
#  '40',
#  '40s',
#  '42',
#  '451',
#  '48',
#  '4ever',
#  '4th',
#  '4w',
#  '50',
#  '500',
#  '50s',
#  '51',
#  '51st',
#  '52',
#  '53',
#  '5ths',
#  '60',
#  '60s',
#  '65',
#  '65th',
#  '66',
#  '70',
#  '70s',
#  '71',
#  '72',
#  '75',
#  '77',
#  '78',
#  '7th',
#  '80',
#  '800',
#  '80s',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '8th',
#  '90',
#  '90s',
#  '91',
#  '93',
#  '94',
#  '95',
#  '96',
#  '98',
#  '99',
#  'aaa',
#  'aaliyah',
#  'aan',
#  'abagnale',
#  'abandon',
#  'abandoned',
#  'abbass',
#  'abbott',
#  'abbreviated',
#  'abc',
#  'abderrahmane',
#  'abdul',
#  'abel',
#  'abhorrent',
#  'abhors',
#  'abiding',
#  'abilities',
#  'ability',
#  'abject',
#  'able',
#  'ably',
#  'abomination',
#  'aboriginal',
#  'aborted',
#  'abound',
#  'about',
#  'above',
#  'abrahams',
#  'abrasive',
#  'abridged',
#  'abroad',
#  'abrupt',
#  'absence',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'absorbs',
#  'absorption',
#  'abstract',
#  'absurd',
#  'absurdist',
#  'absurdities',
#  'absurdity',
#  'absurdly',
#  'abundant',
#  'abundantly',
#  'abuse',
#  'abused',
#  'abysmal',
#  'abyss',
#  'academic',
#  'academy',
#  'accent',
#  'accents',
#  'accentuating',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepting',
#  'accepts',
#  'access',
#  'accessibility',
#  'accessible',
#  'accident',
#  'accidental',
#  'acclaim',
#  'acclaimed',
#  'accommodate',
#  'accomodates',
#  'accompanied',
#  'accompanies',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishment',
#  'accomplishments',
#  'according',
#  'account',
#  'accountant',
#  'accumulate',
#  'accumulated',
#  'accumulates',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accuse',
#  'accused',
#  'ace',
#  'acerbic',
#  'ache',
#  'achero',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'aching',
#  'achingly',
#  'achival',
#  'achronological',
#  'acid',
#  'acidic',
#  'acidity',
#  'ackerman',
#  'acknowledges',
#  'acknowledging',
#  'acolytes',
#  'acquainted',
#  'acquire',
#  'acquired',
#  'acquires',
#  'acres',
#  'acrid',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actioner',
#  'actioners',
#  'actions',
#  'activate',
#  'activism',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actorish',
#  'actorliness',
#  'actorly',
#  'actors',
#  'actory',
#  'actress',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'actuary',
#  'acumen',
#  'acute',
#  'ad',
#  'adage',
#  'adam',
#  'adamant',
#  'adams',
#  'adaptation',
#  'adaptations',
#  'adapted',
#  'adapts',
#  'add',
#  'addams',
#  'added',
#  'addict',
#  'addicted',
#  'addiction',
#  'addictive',
#  'adding',
#  'addition',
#  'address',
#  'addresses',
#  'addressing',
#  'adds',
#  'adept',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adherents',
#  'adhering',
#  'adjective',
#  'adjusting',
#  'administration',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admirers',
#  'admiring',
#  'admission',
#  'admit',
#  'admitted',
#  'admittedly',
#  'admitting',
#  'ado',
#  'adobo',
#  'adolescence',
#  'adolescent',
#  'adolescents',
#  'adopt',
#  'adopts',
#  'adorability',
#  'adorable',
#  'adorably',
#  'adored',
#  'adoring',
#  'adorns',
#  'adrenalin',
#  'adrenaline',
#  'adrenalized',
#  'adrian',
#  'adrien',
#  'adrift',
#  'adroit',
#  'ads',
#  'adult',
#  'adultery',
#  'adults',
#  'advance',
#  'advanced',
#  'advances',
#  'advancing',
#  'advantage',
#  'advantages',
#  'adventues',
#  'adventure',
#  'adventures',
#  'adventurous',
#  'adversity',
#  'advert',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advised',
#  'advises',
#  'advocacy',
#  'aerial',
#  'aesop',
#  'aesthetic',
#  'aesthetically',
#  'aesthetics',
#  'affability',
#  'affable',
#  'affair',
#  'affect',
#  'affectation',
#  'affected',
#  'affecting',
#  'affectingly',
#  'affection',
#  'affectionate',
#  'affectionately',
#  'affections',
#  'affects',
#  'affinity',
#  'affirm',
#  'affirmational',
#  'affirming',
#  'affirms',
#  'affleck',
#  'afflicts',
#  'affluence',
#  'affluent',
#  'afford',
#  'affords',
#  'afghan',
#  'afghani',
#  'aficionados',
#  'afloat',
#  'afraid',
#  'africa',
#  'african',
#  'after',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'afterschool',
#  'aftertaste',
#  'afterthought',
#  'afterwards',
#  'again',
#  'against',
#  'agape',
#  'age',
#  'aged',
#  'agency',
#  'agenda',
#  'agendas',
#  'agent',
#  'agents',
#  'agers',
#  'ages',
#  'agey',
#  'aggrandizing',
#  'aggravating',
#  'aggressive',
#  'aggressively',
#  'aggressiveness',
#  'aggrieved',
#  'agile',
#  'aging',
#  'agitator',
#  'agitprop',
#  'agnostic',
#  'ago',
#  'agonizing',
#  'agony',
#  'agreeably',
#  'agreed',
#  'agreement',
#  'aground',
#  'ah',
#  'ahead',
#  'ahem',
#  'ahola',
#  'ai',
#  'aid',
#  'aided',
#  'aids',
#  'aiello',
#  'ailments',
#  'aim',
#  'aimed',
#  'aiming',
#  'aimless',
#  'aimlessly',
#  'aimlessness',
#  'aims',
#  'air',
#  'aircraft',
#  'airhead',
#  'airless',
#  'airs',
#  'airy',
#  'aisle',
#  'aisles',
#  'akin',
#  'al',
#  'alabama',
#  'alacrity',
#  'aladdin',
#  'alagna',
#  'alain',
#  'alan',
#  'alarming',
#  'alarms',
#  'alas',
#  'albeit',
#  'album',
#  'alcatraz',
#  'alchemical',
#  'aldrich',
#  'aleck',
#  'alert',
#  'alexander',
#  'alexandre',
#  'alfonso',
#  'alfred',
#  'ali',
#  'alias',
#  'alice',
#  'alien',
#  'alienate',
#  'alienated',
#  'alienating',
#  'alienation',
#  'aliens',
#  'alike',
#  'alive',
#  'all',
#  'alleged',
#  'allegedly',
#  'allegiance',
#  'allegory',
#  'allen',
#  'allied',
#  'allison',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'alluring',
#  'allusions',
#  'ally',
#  'almodovar',
#  'almost',
#  'aloft',
#  'alone',
#  'along',
#  'alongside',
#  'aloof',
#  'already',
#  'also',
#  'alt',
#  'altar',
#  'alter',
#  'alterations',
#  'altered',
#  'altering',
#  'alternate',
#  'alternately',
#  'alternates',
#  'alternating',
#  'alternative',
#  'alternatives',
#  'although',
#  'altman',
#  'altogether',
#  'always',
#  'am',
#  'amalgam',
#  'amari',
#  'amaro',
#  'amassed',
#  'amateur',
#  'amateurish',
#  'amateurishly',
#  'amaze',
#  'amazement',
#  'amazing',
#  'amazingly',
#  'ambience',
#  'ambiguities',
#  'ambiguity',
#  'ambiguous',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'ambitiously',
#  'ambivalence',
#  'ambivalent',
#  'amble',
#  'ambrose',
#  'amc',
#  'ame',
#  'america',
#  'american',
#  'americanized',
#  'americans',
#  'amiable',
#  'amiably',
#  'amicable',
#  'amid',
#  'amidst',
#  'amini',
#  'amir',
#  'amish',
#  'amiss',
#  'amnesiac',
#  'amok',
#  'among',
#  'amoral',
#  'amorality',
#  'amorous',
#  'amos',
#  'amount',
#  'amounts',
#  'amours',
#  'amp',
#  'ample',
#  'amuse',
#  'amused',
#  'amusedly',
#  'amusement',
#  'amusements',
#  'amuses',
#  'amusing',
#  'amy',
#  'an',
#  'ana',
#  'anachronistic',
#  'anakin',
#  'analgesic',
#  'analysis',
#  'analytical',
#  'analyze',
#  'anarchic',
#  'anarchist',
#  'anarchists',
#  'anarchy',
#  'anatomical',
#  'anchor',
#  'anchored',
#  'anchoring',
#  'anchors',
#  'ancient',
#  'anciently',
#  'ancillary',
#  'and',
#  'anderson',
#  'andie',
#  'andrei',
#  'android',
#  'anecdote',
#  'anemic',
#  'anew',
#  'angel',
#  'angela',
#  'angeles',
#  'angelina',
#  'angelique',
#  'angels',
#  'anger',
#  'angle',
#  'angles',
#  'angling',
#  'angry',
#  'angst',
#  'anguish',
#  'anguished',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'animations',
#  'animaton',
#  'animator',
#  'animatronic',
#  'anime',
#  'aniston',
#  'ankle',
#  'anna',
#  'annals',
#  'anne',
#  'annex',
#  'annie',
#  'anniversary',
#  'annoyance',
#  'annoyances',
#  'annoyed',
#  'annoying',
#  'annual',
#  'anomaly',
#  'anomie',
#  'anonymity',
#  'anonymous',
#  'another',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'antagonism',
#  'ante',
#  'anteing',
#  'anthology',
#  'anthony',
#  'anthropology',
#  'anthropomorphic',
#  'anti',
#  'antic',
#  'anticipated',
#  'anticipation',
#  'antics',
#  'antidote',
#  'antique',
#  'antiseptic',
#  'antitrust',
#  'anton',
#  'antonia',
#  'antonio',
#  'ants',
#  'antsy',
#  'antwone',
#  'anxieties',
#  'anxious',
#  'any',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anyplace',
#  'anything',
#  'anyway',
#  'anywhere',
#  'apart',
#  'apartheid',
#  'apartments',
#  'ape',
#  'apes',
#  'apex',
#  'aplenty',
#  'aplomb',
#  'apocalypse',
#  'apollo',
#  'apology',
#  'appalling',
#  'apparatus',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appealing',
#  'appealingly',
#  'appeals',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'appetite',
#  'appetites',
#  'appetizer',
#  'appetizing',
#  'applauded',
#  'apple',
#  'applegate',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appointed',
#  'appreciate',
#  'appreciated',
#  'appreciates',
#  'appreciation',
#  'appreciative',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'appropriated',
#  'appropriately',
#  'approximation',
#  'april',
#  'apted',
#  'aptitude',
#  'aptly',
#  'aragorn',
#  'aranda',
#  'ararat',
#  'arbitrarily',
#  'arbitrary',
#  'arc',
#  'arcane',
#  'arch',
#  'archetypal',
#  'archibald',
#  'architect',
#  'architecture',
#  'archival',
#  'archive',
#  'archives',
#  'archly',
#  'arctic',
#  'ardent',
#  'ardently',
#  'ardor',
#  'arduous',
#  'are',
#  'area',
#  'areas',
#  'argentine',
#  'argentinean',
#  'argentinian',
#  'argento',
#  'argot',
#  'arguably',
#  'argue',
#  'argues',
#  'arguing',
#  'argument',
#  'arguments',
#  'arise',
#  'arising',
#  'aristocracy',
#  'aristocrat',
#  'aristocrats',
#  'arithmetic',
#  'ark',
#  'arkansas',
#  'arliss',
#  'arm',
#  'armageddon',
#  'armchair',
#  'armed',
#  'armenia',
#  'armenian',
#  'armenians',
#  'arms',
#  'arnie',
#  'arnold',
#  'around',
#  'arrangements',
#  'array',
#  'arrest',
#  'arresting',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrogance',
#  'arrogant',
#  'arrow',
#  'art',
#  'artefact',
#  'arteta',
#  'artful',
#  'artfully',
#  'arthouse',
#  'arthur',
#  'articulate',
#  'articulates',
#  'artifice',
#  'artificial',
#  'artificiality',
#  'artist',
#  'artistes',
#  'artistic',
#  'artistically',
#  'artistry',
#  'artists',
#  'artless',
#  'artnering',
#  'arts',
#  'artsploitation',
#  'artsy',
#  'artwork',
#  'artworks',
#  'arty',
#  'arwen',
#  'as',
#  'ascends',
#  'ascension',
#  'ascertain',
#  'ash',
#  'ashamed',
#  'ashley',
#  'asia',
#  'asian',
#  'asiaphiles',
#  'aside',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'asparagus',
#  'aspect',
#  'aspects',
#  'asphalt',
#  'aspiration',
#  'aspirations',
#  'aspire',
#  'aspired',
#  'aspires',
#  'asquith',
#  'assailants',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assault',
#  'assaultive',
#  'assaults',
#  'assayas',
#  'assed',
#  'assembled',
#  'assembles',
#  'assembly',
#  'assert',
#  'assess',
#  'assesses',
#  'asset',
#  'assets',
#  'assign',
#  'assigned',
#  'assignment',
#  'assimilated',
#  'associate',
#  'associated',
#  'association',
#  'associations',
#  'assume',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assurance',
#  'assured',
#  'assuredly',
#  'assures',
#  'astonish',
#  'astonishing',
#  'astonishingly',
#  'astounding',
#  'astoundingly',
#  'astounds',
#  'astray',
#  'astringent',
#  'astronaut',
#  'astronauts',
#  'astronomically',
#  'astute',
#  'asylum',
#  'at',
#  'ate',
#  'athlete',
#  'athletes',
#  'athletic',
#  'athleticism',
#  'athon',
#  'atlantic',
#  'atmosphere',
#  'atmospheric',
#  'atmospherics',
#  'atop',
#  'atrocious',
#  'atrociously',
#  'atrocities',
#  'attach',
#  'attached',
#  'attachment',
#  'attack',
#  'attackers',
#  'attacks',
#  'attal',
#  'attempt',
#  'attempted',
#  'attempts',
#  'attendant',
#  'attending',
#  'attention',
#  'attentions',
#  'attentive',
#  'attics',
#  'attitude',
#  'attitudes',
#  'attract',
#  'attracting',
#  'attraction',
#  'attractions',
#  'attractive',
#  'attracts',
#  'attributable',
#  'attuned',
#  'atypically',
#  'audacious',
#  'audacity',
#  'audiard',
#  'audience',
#  'audiences',
#  'auditorium',
#  'audrey',
#  'augmented',
#  'august',
#  'augustine',
#  'augustinian',
#  'aurelie',
#  'auschwitz',
#  'auspicious',
#  'aussie',
#  'austen',
#  'austere',
#  'austerity',
#  'austin',
#  'australia',
#  'australian',
#  'austrian',
#  'auteil',
#  'auteuil',
#  'auteur',
#  'authentic',
#  'authentically',
#  'authenticate',
#  'authenticity',
#  'author',
#  'authority',
#  ...]

# %%
count.vocabulary_['amazing']
# Out:
# 555
